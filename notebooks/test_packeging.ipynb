# %%
from data import * 
df = get_data_local()
df = clean_data(df)
df = data_reduction(df)
# Out:
# ✅ data received
# ✅ data cleaned
# ✅ randomly removed 4373664 non-fraudulent rows from the data frame.

# %%
from preprocessor import preprocess_features

df = preprocess_features(df)
# Out:
# ✅ data preprocessed
# /Users/Malte/.pyenv/versions/3.10.6/envs/aml_detector/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df
# Out:
#          from_bank from_account  to_bank to_account receiving_currency
# 1173616         10    8016BBF40     2952  801C4F7C0                USD  \
# 4226763      23885    8066F0370   223635  80B580C60                USD
# 1382421      16431    801FD7CB0    25866  80D3C1CE0                EUR
# 1836651      23402    805EC6410   111425  8065C5400                USD
# 538098        6625    8088F49F0   214100  8121BDD90                EUR
# ...            ...          ...      ...        ...                ...
# 4418522     111433    8065C2380    21550  8065C69E0                USD
# 4420644          9    80727F930   219557  8072A28C0                RUB
# 4421490        222    812D127D0    50202  812D129C0                SAR
# 4422275      17327    8095F6C20    15695  8095F6C70                USD
# 4424339          3    804FAA470   212789  804FAD580                INR
#
#         payment_currency payment_format  is_laundering  amount_paid_USD
# ...
